# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from pyomo.environ import *
from random import uniform

# %% [markdown]
# # Загрузка данных

# %%
with open('product_rels.pkl', 'rb') as file:
    product_rels = pickle.load(file)
    
with open('shop_info.pkl', 'rb') as file:
    shop_info = pickle.load(file)
    
prices = pd.read_csv('prices.csv')

# %%
prices.head()
# Out:
#    year_week start_weekday  price_apple  price_banana  price_pear  \
# 0     201931    2019-07-29         90.0          80.0       130.0
# 1     201932    2019-08-05         90.0          80.0       130.0
# 2     201933    2019-08-12         90.0          80.0       130.0
# 3     201934    2019-08-19         90.0          80.0       130.0
# 4     201935    2019-08-26         90.0          80.0       130.0
#
#    price_orange  price_lemon
# 0         100.0        110.0
# 1         100.0        110.0
# 2         100.0        110.0
# 3         100.0        110.0
# 4         100.0        110.0

# %%
product_rels
# Out:
# {('apple', 'apple'): 0,
#  ('apple', 'banana'): 0.15,
#  ('apple', 'pear'): -0.15,
#  ('apple', 'orange'): 0.17,
#  ('apple', 'lemon'): 0.17,
#  ('banana', 'apple'): 0.15,
#  ('banana', 'banana'): 0,
#  ('banana', 'pear'): 0.12,
#  ('banana', 'orange'): 0.1,
#  ('banana', 'lemon'): 0.1,
#  ('pear', 'apple'): -0.15,
#  ('pear', 'banana'): 0.12,
#  ('pear', 'pear'): 0,
#  ('pear', 'orange'): 0.12,
#  ('pear', 'lemon'): 0.12,
#  ('orange', 'apple'): 0.17,
#  ('orange', 'banana'): 0.1,
#  ('orange', 'pear'): 0.12,
#  ('orange', 'orange'): 0,
#  ('orange', 'lemon'): -0.19,
#  ('lemon', 'apple'): 0.17,
#  ('lemon', 'banana'): 0.1,
#  ('lemon', 'pear'): 0.12,
#  ('lemon', 'orange'): -0.19,
#  ('lemon', 'lemon'): 0}

# %%
shop_info
# Out:
# {0: {'shop_id': '0c82a0ea628e0ec608d70d1db9d822d9',
#   'shop_size_coef': 1,
#   'apple': 825.0,
#   'banana': 309.0,
#   'pear': 416.0,
#   'orange': 522.0,
#   'lemon': 571.0},
#  1: {'shop_id': '0e0b24fc303d2b384be5a2464654a5d2',
#   'shop_size_coef': 1,
#   'apple': 618.0,
#   'banana': 358.0,
#   'pear': 459.0,
#   'orange': 460.0,
#   'lemon': 657.0},
#  2: {'shop_id': '0e7e3cf0ded4d9db8b376b317c007f99',
#   'shop_size_coef': 2,
#   'apple': 2144.0,
#   'banana': 1020.0,
#   'pear': 1147.0,
#   'orange': 1660.0,
#   'lemon': 1599.0},
#  3: {'shop_id': '155d328d7db586cf215aca5e8088dfed',
#   'shop_size_coef': 2,
#   'apple': 727.0,
#   'banana': 349.0,
#   'pear': 418.0,
#   'orange': 556.0,
#   'lemon': 437.0},
#  4: {'shop_id': '1640f59af9fc45f93a72652de254d387',
#   'shop_size_coef': 1,
#   'apple': 667.0,
#   'banana': 272.0,
#   'pear': 409.0,
#   'orange': 556.0,
#   'lemon': 634.0},
#  5: {'shop_id': '171293841d3fdd4af2e12426ce202ac9',
#   'shop_size_coef': 2,
#   'apple': 2067.0,
#   'banana': 911.0,
#   'pear': 1288.0,
#   'orange': 1366.0,
#   'lemon': 1750.0},
#  6: {'shop_id': '198f9e9f064617952401a90cfbff7461',
#   'shop_size_coef': 1,
#   'apple': 630.0,
#   'banana': 347.0,
#   'pear': 394.0,
#   'orange': 478.0,
#   'lemon': 585.0},
#  7: {'shop_id': '19a6a0b9360519fe82b5b06b3f79d62c',
#   'shop_size_coef': 1,
#   'apple': 676.0,
#   'banana': 272.0,
#   'pear': 359.0,
#   'orange': 564.0,
#   'lemon': 593.0},
#  8: {'shop_id': '24a41dfc0b09c248bbc23b5e1ffc16d8',
#   'shop_size_coef': 1,
#   'apple': 671.0,
#   'banana': 327.0,
#   'pear': 368.0,
#   'orange': 464.0,
#   'lemon': 658.0},
#  9: {'shop_id': '25bbdcd06c32d477f7fa1c3e4a91b032',
#   'shop_size_coef': 1,
#   'apple': 699.0,
#   'banana': 352.0,
#   'pear': 367.0,
#   'orange': 449.0,
#   'lemon': 583.0},
#  10: {'shop_id': '29150bb2319c182c944841c74d2f8d75',
#   'shop_size_coef': 1,
#   'apple': 664.0,
#   'banana': 355.0,
#   'pear': 475.0,
#   'orange': 476.0,
#   'lemon': 565.0},
#  11: {'shop_id': '29549a71a57f587d88209b9c1f1b7999',
#   'shop_size_coef': 2,
#   'apple': 2283.0,
#   'banana': 870.0,
#   'pear': 1204.0,
#   'orange': 1373.0,
#   'lemon': 1876.0},
#  12: {'shop_id': '2a34e8685490c86e180af62f6f0f4f87',
#   'shop_size_coef': 1,
#   'apple': 632.0,
#   'banana': 325.0,
#   'pear': 434.0,
#   'orange': 441.0,
#   'lemon': 462.0},
#  13: {'shop_id': '2d17b1cd9f1f0c85bb90adad7c25ac5e',
#   'shop_size_coef': 2,
#   'apple': 2131.0,
#   'banana': 1022.0,
#   'pear': 1127.0,
#   'orange': 1360.0,
#   'lemon': 1778.0},
#  14: {'shop_id': '2f8639feef43f2964be0cee184dad78c',
#   'shop_size_coef': 1,
#   'apple': 780.0,
#   'banana': 334.0,
#   'pear': 397.0,
#   'orange': 464.0,
#   'lemon': 579.0},
#  15: {'shop_id': '3a1e655328599b6a1208115f2271c942',
#   'shop_size_coef': 1,
#   'apple': 805.0,
#   'banana': 377.0,
#   'pear': 407.0,
#   'orange': 462.0,
#   'lemon': 515.0},
#  16: {'shop_id': '4f1ac1f615a1c3414134c2d3ae9a3f58',
#   'shop_size_coef': 1,
#   'apple': 707.0,
#   'banana': 244.0,
#   'pear': 380.0,
#   'orange': 556.0,
#   'lemon': 575.0},
#  17: {'shop_id': '5072ec0261a35740089ed41e844e51eb',
#   'shop_size_coef': 2,
#   'apple': 2239.0,
#   'banana': 1033.0,
#   'pear': 1422.0,
#   'orange': 1594.0,
#   'lemon': 1841.0},
#  18: {'shop_id': '540bd55a2cf295b8ea9cd78650e89d03',
#   'shop_size_coef': 2,
#   'apple': 1882.0,
#   'banana': 1145.0,
#   'pear': 1178.0,
#   'orange': 1560.0,
#   'lemon': 1927.0},
#  19: {'shop_id': '5bbac39cd13478e3c41463540d032c22',
#   'shop_size_coef': 1,
#   'apple': 872.0,
#   'banana': 306.0,
#   'pear': 470.0,
#   'orange': 499.0,
#   'lemon': 669.0},
#  20: {'shop_id': '605b3386cb5ef25b8d60d1bacfeeab7a',
#   'shop_size_coef': 1,
#   'apple': 647.0,
#   'banana': 364.0,
#   'pear': 442.0,
#   'orange': 484.0,
#   'lemon': 550.0},
#  21: {'shop_id': '6858fb45a3d3aef7c29322d3b68dffd1',
#   'shop_size_coef': 2,
#   'apple': 2039.0,
#   'banana': 1003.0,
#   'pear': 1020.0,
#   'orange': 1413.0,
#   'lemon': 1788.0},
#  22: {'shop_id': '6950aac2d7932e1f1a4c3cf6ada1316e',
#   'shop_size_coef': 1,
#   'apple': 681.0,
#   'banana': 356.0,
#   'pear': 408.0,
#   'orange': 559.0,
#   'lemon': 529.0},
#  23: {'shop_id': '73cc1f9b54baa5917ae240b96c832690',
#   'shop_size_coef': 1,
#   'apple': 712.0,
#   'banana': 311.0,
#   'pear': 407.0,
#   'orange': 454.0,
#   'lemon': 669.0},
#  24: {'shop_id': '785ee201dc63daae3aecb2c7cbae60d3',
#   'shop_size_coef': 1,
#   'apple': 667.0,
#   'banana': 309.0,
#   'pear': 494.0,
#   'orange': 522.0,
#   'lemon': 500.0},
#  25: {'shop_id': '78c734ebceead5b7b07ffd1414b22eed',
#   'shop_size_coef': 1,
#   'apple': 664.0,
#   'banana': 388.0,
#   'pear': 438.0,
#   'orange': 501.0,
#   'lemon': 538.0},
#  26: {'shop_id': '7cd86ecb09aa48c6e620b340f6a74592',
#   'shop_size_coef': 2,
#   'apple': 2264.0,
#   'banana': 991.0,
#   'pear': 1021.0,
#   'orange': 1478.0,
#   'lemon': 1636.0},
#  27: {'shop_id': '7dd5071ff43138f6756e30f4b271c4ac',
#   'shop_size_coef': 1,
#   'apple': 692.0,
#   'banana': 296.0,
#   'pear': 410.0,
#   'orange': 431.0,
#   'lemon': 532.0},
#  28: {'shop_id': '7f1a65908b05238c21c134c764c89e28',
#   'shop_size_coef': 1,
#   'apple': 754.0,
#   'banana': 337.0,
#   'pear': 353.0,
#   'orange': 474.0,
#   'lemon': 584.0},
#  29: {'shop_id': '7f8bb0fe8b33780a08fe6b60ced14529',
#   'shop_size_coef': 2,
#   'apple': 1755.0,
#   'banana': 982.0,
#   'pear': 1204.0,
#   'orange': 1662.0,
#   'lemon': 1885.0},
#  30: {'shop_id': '8566418f640c84b79671a915d659087d',
#   'shop_size_coef': 1,
#   'apple': 655.0,
#   'banana': 311.0,
#   'pear': 373.0,
#   'orange': 550.0,
#   'lemon': 630.0},
#  31: {'shop_id': '857778a20b9a41d4ca0d687a36e4bfa8',
#   'shop_size_coef': 1,
#   'apple': 736.0,
#   'banana': 314.0,
#   'pear': 435.0,
#   'orange': 430.0,
#   'lemon': 545.0},
#  32: {'shop_id': '87277281b55376d0231ad94f63e4a7eb',
#   'shop_size_coef': 1,
#   'apple': 720.0,
#   'banana': 318.0,
#   'pear': 390.0,
#   'orange': 479.0,
#   'lemon': 673.0},
#  33: {'shop_id': '9061198a99f995e44314503d643e49a8',
#   'shop_size_coef': 1,
#   'apple': 744.0,
#   'banana': 307.0,
#   'pear': 430.0,
#   'orange': 488.0,
#   'lemon': 657.0},
#  34: {'shop_id': '926abae84a4bd33c834bc6b981b8cf30',
#   'shop_size_coef': 2,
#   'apple': 2169.0,
#   'banana': 935.0,
#   'pear': 1012.0,
#   'orange': 1585.0,
#   'lemon': 1852.0},
#  35: {'shop_id': '95b09698fda1f64af16708ffb859eab9',
#   'shop_size_coef': 2,
#   'apple': 2356.0,
#   'banana': 831.0,
#   'pear': 1132.0,
#   'orange': 1689.0,
#   'lemon': 1589.0},
#  36: {'shop_id': 'a3363a6147d5ccb2bbd06d1fa3c7f276',
#   'shop_size_coef': 2,
#   'apple': 1909.0,
#   'banana': 858.0,
#   'pear': 1293.0,
#   'orange': 1509.0,
#   'lemon': 1612.0},
#  37: {'shop_id': 'a4bab3ce420ea5342f99b468206738eb',
#   'shop_size_coef': 1,
#   'apple': 763.0,
#   'banana': 262.0,
#   'pear': 333.0,
#   'orange': 553.0,
#   'lemon': 529.0},
#  38: {'shop_id': 'a9b2b0ce7799c4de9c7a3aed9ebeddeb',
#   'shop_size_coef': 1,
#   'apple': 750.0,
#   'banana': 319.0,
#   'pear': 420.0,
#   'orange': 546.0,
#   'lemon': 548.0},
#  39: {'shop_id': 'ab1048060528a978a536ee2e9538de28',
#   'shop_size_coef': 1,
#   'apple': 722.0,
#   'banana': 343.0,
#   'pear': 361.0,
#   'orange': 517.0,
#   'lemon': 577.0},
#  40: {'shop_id': 'ae2bac2e4b4da805d01b2952d7e35ba4',
#   'shop_size_coef': 2,
#   'apple': 2298.0,
#   'banana': 972.0,
#   'pear': 1242.0,
#   'orange': 1320.0,
#   'lemon': 1765.0},
#  41: {'shop_id': 'b705667936f5d49b801c56aa43bed5ea',
#   'shop_size_coef': 1,
#   'apple': 738.0,
#   'banana': 314.0,
#   'pear': 434.0,
#   'orange': 445.0,
#   'lemon': 578.0},
#  42: {'shop_id': 'b94d71e6bc4cc21ffbaaef5e4aca6f03',
#   'shop_size_coef': 1,
#   'apple': 739.0,
#   'banana': 335.0,
#   'pear': 420.0,
#   'orange': 464.0,
#   'lemon': 659.0},
#  43: {'shop_id': 'bc0137b31ec76a5db842d365640116bd',
#   'shop_size_coef': 2,
#   'apple': 2209.0,
#   'banana': 1173.0,
#   'pear': 1095.0,
#   'orange': 1249.0,
#   'lemon': 1723.0},
#  44: {'shop_id': 'bda8f8645db921d24845639f76635574',
#   'shop_size_coef': 1,
#   'apple': 711.0,
#   'banana': 361.0,
#   'pear': 385.0,
#   'orange': 472.0,
#   'lemon': 480.0},
#  45: {'shop_id': 'c0279f73075a52e1a7dea35065bc8c80',
#   'shop_size_coef': 1,
#   'apple': 689.0,
#   'banana': 279.0,
#   'pear': 306.0,
#   'orange': 521.0,
#   'lemon': 500.0},
#  46: {'shop_id': 'ca0a908e85ac27b2cd0d2b82b3e374e5',
#   'shop_size_coef': 2,
#   'apple': 1879.0,
#   'banana': 1029.0,
#   'pear': 1293.0,
#   'orange': 1499.0,
#   'lemon': 1700.0},
#  47: {'shop_id': 'cd6ebdcfe9b6f0ce7ac05d8848a8c956',
#   'shop_size_coef': 2,
#   'apple': 2216.0,
#   'banana': 819.0,
#   'pear': 1353.0,
#   'orange': 1563.0,
#   'lemon': 1636.0},
#  48: {'shop_id': 'd04feef70623eaf7167f9172da8650db',
#   'shop_size_coef': 1,
#   'apple': 672.0,
#   'banana': 319.0,
#   'pear': 448.0,
#   'orange': 507.0,
#   'lemon': 604.0},
#  49: {'shop_id': 'd25922edb7ab92c0ca31328cbdcbd42f',
#   'shop_size_coef': 1,
#   'apple': 691.0,
#   'banana': 281.0,
#   'pear': 378.0,
#   'orange': 472.0,
#   'lemon': 516.0},
#  50: {'shop_id': 'd39934ce111a864abf40391f3da9cdf5',
#   'shop_size_coef': 2,
#   'apple': 2226.0,
#   'banana': 1119.0,
#   'pear': 900.0,
#   'orange': 1412.0,
#   'lemon': 1593.0},
#  51: {'shop_id': 'e90b327c1ceca11f1a44a8bcf58af34c',
#   'shop_size_coef': 1,
#   'apple': 784.0,
#   'banana': 315.0,
#   'pear': 409.0,
#   'orange': 444.0,
#   'lemon': 608.0},
#  52: {'shop_id': 'e960bd3154493f20a5a54c28f5686d4e',
#   'shop_size_coef': 1,
#   'apple': 795.0,
#   'banana': 301.0,
#   'pear': 451.0,
#   'orange': 493.0,
#   'lemon': 603.0},
#  53: {'shop_id': 'ecee596a242de13b779391cdaa2c528d',
#   'shop_size_coef': 1,
#   'apple': 859.0,
#   'banana': 312.0,
#   'pear': 464.0,
#   'orange': 534.0,
#   'lemon': 615.0},
#  54: {'shop_id': 'f865c5e07958ad70ef989e905390f6d0',
#   'shop_size_coef': 1,
#   'apple': 770.0,
#   'banana': 350.0,
#   'pear': 464.0,
#   'orange': 462.0,
#   'lemon': 637.0},
#  55: {'shop_id': 'f90a337271004d00cbd620a61844401a',
#   'shop_size_coef': 1,
#   'apple': 870.0,
#   'banana': 409.0,
#   'pear': 459.0,
#   'orange': 526.0,
#   'lemon': 614.0},
#  56: {'shop_id': 'fbc01d515dac182ba3524a3b11fdf4b2',
#   'shop_size_coef': 1,
#   'apple': 668.0,
#   'banana': 328.0,
#   'pear': 297.0,
#   'orange': 499.0,
#   'lemon': 616.0},
#  57: {'shop_id': 'fc1198178c3594bfdda3ca2996eb65cb',
#   'shop_size_coef': 2,
#   'apple': 2071.0,
#   'banana': 957.0,
#   'pear': 1325.0,
#   'orange': 1715.0,
#   'lemon': 1813.0},
#  58: {'shop_id': 'fcd04e26e900e94b9ed6dd604fed2b64',
#   'shop_size_coef': 1,
#   'apple': 588.0,
#   'banana': 381.0,
#   'pear': 451.0,
#   'orange': 529.0,
#   'lemon': 537.0}}

# %%
prices = prices.head(24)

# %%
products = ['apple', 'banana', 'pear', 'orange', 'lemon']

# %%
S = len(shop_info)
W = 24
P = len(products)

# %% [markdown]
# # Оптимизация с помощью Pyomo

# %%
def L(s: int, p: int, w: int, R: list) -> float:
    result = 0
    for o in range(p):
        r_ow = R[o][w]
        r_ow_seasonal = prices.loc[w][f'price_{products[o]}']
        C_po = product_rels[(products[p], products[o])]
        M_so = shop_info[s][products[o]]
        result += (r_ow_seasonal / r_ow) ** 2 * C_po * M_so
    return result

# %%
def f(s: int, p: int, w: int, R) -> float:
    if 'list' not in str(type(R)):
        R = R.tolist()
    r_pw = R[p][w]
    M_sp = shop_info[s][products[p]]
    r_pw_seasonal = prices.loc[w][f'price_{products[p]}']
    L_spw = L(s, p, w, R)
    return r_pw * (M_sp * (-(r_pw / r_pw_seasonal) ** 2 - 0.075 * r_pw / r_pw_seasonal + 2.85) / 1.775 + L_spw)

# %%
def optimize_prices() -> list: # возвращает матрицу цен
    
    def var_matrix_to_list(var: Var, dim1: int, dim2: int) -> list:
        return [[var[i, j] for j in range(1, dim2 + 1)] for i in range(1, dim1 + 1)]
    
    model = ConcreteModel()
    
    model.r = Var(range(1, P + 1), range(1, W + 1), domain=PositiveIntegers)
    
    model.objective = Objective(
        expr=quicksum(quicksum(quicksum(f(s, p, w, var_matrix_to_list(model.r, P, W)) 
                                        for w in range(W)) for p in range(P)) for s in range(S)), 
        sense=maximize)
    
    model.constraints = ConstraintList()
    for p in range(P):
        for w in range(W):
            r_pw_seasonal = prices.loc[w][f'price_{products[p]}']
            model.constraints.add(0.75 * r_pw_seasonal <= model.r[p + 1, w + 1])
            model.constraints.add(model.r[p + 1, w + 1] <= 1.25 * r_pw_seasonal)
    
    solver = SolverFactory('ipopt')
    result = solver.solve(model, tee=True)
    
    return [[model.r[p, w].value for w in range(1, W + 1)] for p in range(1, P + 1)]

# %%
optimal_model = optimize_prices()
r_optimal = [[optimal_model.r[p, w].value for w in range(1, W + 1)] for p in range(1, P + 1)]
# Out:
# Ipopt 3.11.1:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# This is Ipopt version 3.11.1, running with linear solver mumps.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:      240
# Number of nonzeros in Lagrangian Hessian.............:      360
#
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Error evaluating objective gradient at user provided starting point.
#   No scaling factor for objective function computed!
# Total number of variables............................:      120
#                      variables with only lower bounds:      120
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:      240
#         inequality constraints with only lower bounds:      120
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      120
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.2870121e+009 9.65e+001 3.65e+008  -1.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 -4.9629025e+009 9.60e+001 9.45e+009  -1.0 6.42e+001  10.0 2.97e-004 1.47e-002h  1
#    2 -4.9472617e+009 9.60e+001 9.48e+009  -1.0 6.33e+001   9.5 1.51e-002 1.49e-004h  1
#    3r-4.9472617e+009 9.60e+001 9.99e+002   2.0 0.00e+000   9.0 0.00e+000 3.64e-007R  3
#    4r-5.6963832e+008 3.83e+001 6.81e+002   2.0 1.82e+002    -  1.00e+000 3.17e-001f  1
#    5 -5.6976937e+008 3.80e+001 2.27e+008  -1.0 2.60e+001   8.6 9.97e-001 2.36e-002f  1
#    6 -5.6977070e+008 3.80e+001 2.28e+008  -1.0 2.54e+001   8.1 1.00e+000 2.42e-004f  1
#    7 -5.6977256e+008 3.80e+001 1.35e+009  -1.0 2.51e+001   7.6 1.00e+000 1.22e-004f  1
#    8 -5.6999785e+008 3.72e+001 7.23e+008  -1.0 3.62e+001   7.1 1.00e+000 2.11e-002f  1
#    9 -5.7297003e+008 3.44e+001 7.25e+008  -1.0 3.73e+001    -  1.67e-002 7.71e-002f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -5.7834831e+008 2.93e+001 6.79e+008  -1.0 3.44e+001    -  8.39e-002 1.46e-001f  1
#   11 -5.8586738e+008 2.28e+001 1.10e+008  -1.0 2.94e+001    -  9.53e-001 2.23e-001f  1
#   12 -6.0680224e+008 2.02e+000 1.92e+007  -1.0 2.29e+001    -  1.99e-001 9.09e-001f  1
#   13 -6.1226793e+008 8.37e-001 2.57e+007  -1.0 3.23e+001    -  3.67e-002 5.67e-001f  1
#   14 -6.1327555e+008 2.86e-001 1.14e+007  -1.0 1.07e+001    -  5.67e-001 6.15e-001f  1
#   15 -6.1794984e+008 9.33e-002 1.26e+007  -1.0 1.67e+001    -  2.77e-002 6.69e-001f  1
#   16 -6.2156911e+008 3.46e-002 8.88e+006  -1.0 2.54e+001    -  3.11e-001 6.16e-001f  1
#   17 -6.2230432e+008 1.37e-003 2.51e+006  -1.0 1.08e+001    -  7.24e-001 9.35e-001f  1
#   18 -6.2242573e+008 0.00e+000 1.64e+006  -1.0 5.44e-001    -  3.52e-001 1.00e+000f  1
#   19 -6.2845983e+008 0.00e+000 1.61e+006  -1.0 2.14e+001    -  1.53e-002 1.00e+000f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -6.3054882e+008 0.00e+000 1.15e+006  -1.0 1.85e+001    -  2.89e-001 1.00e+000f  1
#   21 -6.3501536e+008 0.00e+000 1.07e+006  -1.0 3.41e+001    -  6.49e-002 1.00e+000f  1
#   22 -6.3514856e+008 0.00e+000 3.83e+005  -1.0 3.84e+000    -  6.43e-001 1.00e+000f  1
#   23 -6.3742514e+008 0.00e+000 3.74e+005  -1.0 8.45e+000    -  2.25e-002 1.00e+000f  1
#   24 -6.4206576e+008 0.00e+000 3.06e+005  -1.0 2.95e+001    -  1.82e-001 1.00e+000f  1
#   25 -6.4744795e+008 0.00e+000 2.47e+005  -1.0 3.16e+001    -  1.94e-001 1.00e+000f  1
#   26 -6.4762309e+008 0.00e+000 1.90e+005  -1.0 2.91e+000    -  2.29e-001 1.00e+000f  1
#   27 -6.4821875e+008 0.00e+000 1.90e+005  -1.0 2.34e+000    -  2.97e-003 1.00e+000f  1
#   28 -6.5983492e+008 0.00e+000 1.83e+005  -1.0 3.58e+001    -  1.18e-003 1.00e+000f  1
#   29 -6.6215573e+008 0.00e+000 1.02e+005  -1.0 1.27e+001    -  4.43e-001 1.00e+000f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30 -6.6374422e+008 0.00e+000 7.63e+004  -1.0 1.38e+001    -  2.52e-001 1.00e+000f  1
#   31 -6.6838863e+008 0.00e+000 6.84e+004  -1.0 3.84e+001    -  1.03e-001 1.00e+000f  1
#   32 -6.6851280e+008 0.00e+000 6.76e+002  -1.0 4.95e+000    -  9.90e-001 1.00e+000f  1
#   33 -6.6851784e+008 0.00e+000 5.07e+000  -1.0 9.87e-002    -  9.92e-001 1.00e+000f  1
#   34 -6.6851798e+008 0.00e+000 9.23e-004  -2.5 6.19e-004    -  1.00e+000 9.98e-001f  1
#   35 -6.6851798e+008 0.00e+000 9.45e-011  -5.7 1.77e-006    -  1.00e+000 1.00e+000f  1
#   36 -6.6851798e+008 0.00e+000 6.83e-011  -9.0 2.15e-010    -  1.00e+000 1.00e+000f  1
#
# Number of Iterations....: 36
#
#                                    (scaled)                 (unscaled)
# Objective...............: -6.6851797792803550e+008  -6.6851797792803550e+008
# Dual infeasibility......:  6.8265191864383717e-011   6.8265191864383717e-011
# Constraint violation....:  0.0000000000000000e+000   0.0000000000000000e+000
# Complementarity.........:  1.2236559598272595e-009   1.2236559598272595e-009
# Overall NLP error.......:  1.4421624339832856e-011   1.2236559598272595e-009
#
#
# Number of objective function evaluations             = 40
# Number of objective gradient evaluations             = 37
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 40
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 38
# Number of Lagrangian Hessian evaluations             = 36
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.098
# Total CPU secs in NLP function evaluations           =      0.691
#
# EXIT: Optimal Solution Found.

# %%
for i in range(len(r_optimal)):
    for j in range(len(r_optimal[i])):
        r_optimal[i][j] = round(r_optimal[i][j], 2)

# %% [markdown]
# # Построение графика

# %%
r_min = [[0.75 * prices.loc[w][f'price_{products[p]}'] for w in range(W)] for p in range(P)]
r_max = [[1.25 * prices.loc[w][f'price_{products[p]}'] for w in range(W)] for p in range(P)]
r_seasonal = [[prices.loc[w][f'price_{products[p]}'] for w in range(W)] for p in range(P)]
r_random = [[uniform(0.75 * prices.loc[w][f'price_{products[p]}'], 1.25 * prices.loc[w][f'price_{products[p]}']) for w in range(W)] for p in range(P)]

# %%
revenues_optimal, revenues_min, revenues_max, revenues_seasonal, revenues_random = [], [], [], [], []

for w in range(W):
    revenues_optimal.append(sum(sum(f(s, p, w, r_optimal) for p in range(P)) for s in range(S)))
    revenues_min.append(sum(sum(f(s, p, w, r_min) for p in range(P)) for s in range(S)))
    revenues_max.append(sum(sum(f(s, p, w, r_max) for p in range(P)) for s in range(S)))
    revenues_seasonal.append(sum(sum(f(s, p, w, r_seasonal) for p in range(P)) for s in range(S)))
    revenues_random.append(sum(sum(f(s, p, w, r_random) for p in range(P)) for s in range(S)))

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(W), revenues_optimal, label='optimal')
plt.plot(range(W), revenues_min, label='min')
plt.plot(range(W), revenues_max, label='max')
plt.plot(range(W), revenues_seasonal, label='seasonal')
plt.plot(range(W), revenues_random, label='random')
plt.xlabel('Номер недели')
plt.ylabel('Выручка')
plt.legend(loc='upper right')

# %% [markdown]
# Как можно видеть на графике, выручка при ценах r_optimal оказывается максимальной из возможных вариантов.

# %% [markdown]
# # Задание со *

# %%
r_seasonal = np.array(prices.drop(['year_week', 'start_weekday'], axis=1)).T

# %%
def optimize_prices_with_promotions(n: int = 5):
    
    def var_matrix_to_numpy(var: Var, dim1: int, dim2: int):
        return np.array([[var[i, j] for j in range(1, dim2 + 1)] for i in range(1, dim1 + 1)])
    
    if n == P:
        return optimize_prices()
    
    model = ConcreteModel()
    
    model.x = Var(range(1, P + 1), range(1, W + 1), domain=Reals, bounds=[-0.25, 0.25])
    model.b = Var(range(1, P + 1), range(1, W + 1), domain=Binary, initialize=0)
        
    model.objective = Objective(
        expr=quicksum(
            quicksum(
            quicksum(
                f(s, p, w, 
                      np.multiply(r_seasonal, 
                                  (np.ones((P, W)) + np.multiply(var_matrix_to_numpy(model.x, P, W),
                                                                 var_matrix_to_numpy(model.b, P, W))))) 
                                        for w in range(W)) for p in range(P)) for s in range(S)), 
        sense=maximize)
    
    model.constraints = ConstraintList()            
    for w in range(1, W + 1):
        model.constraints.add(quicksum(model.b[p, w] for p in range(1, P + 1)) <= n)
        
    solver = SolverFactory('bonmin')
    result = solver.solve(model, tee=True)
    
    x = [[model.x[p, w].value for w in range(1, W + 1)] for p in range(1, P + 1)]
    b = [[model.b[p, w].value for w in range(1, W + 1)] for p in range(1, P + 1)]
    r = np.multiply(r_seasonal, (np.ones((P, W)) + np.multiply(np.array(x), np.array(b))))
    
    return r

# %%
r = [optimize_prices_with_promotions(n) for n in range(0, 6)]
# Out:
# Bonmin 1.3 using Cbc 2.4.2 and Ipopt 3.8.1
# bonmin:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Common Public License (CPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.0759e+008    92       2.557
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.0759e+008    4        0.121
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.0759e+008    4        0.117
# Cbc0012I Integer solution of -6.07589e+008 found by DiveMIPFractional after 0 iterations and 0 nodes (0.26 seconds)
# NLP0014I      2        OPT         -6.0759e+008    4        0.132
# NLP0014I      3        OPT         -6.0759e+008    4        0.12
# Cbc0001I Search completed - best objective -607588580.8499999, took 0 iterations and 0 nodes (0.52 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
#
#  	"Finished"
# Bonmin 1.3 using Cbc 2.4.2 and Ipopt 3.8.1
# bonmin:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Common Public License (CPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.3132e+008    122      3.548
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.3126e+008    15       0.463
# NLP0014I      2        OPT         -6.312e+008     15       0.469
# NLP0014I      3        OPT         -6.3114e+008    15       0.467
# NLP0014I      4        OPT         -6.3108e+008    15       0.492
# NLP0014I      5        OPT         -6.3102e+008    15       0.463
# NLP0014I      6        OPT         -6.3095e+008    17       0.565
# NLP0014I      7        OPT         -6.3095e+008    7        0.205
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.3095e+008    7        0.231
# Cbc0012I Integer solution of -6.30955e+008 found by DiveMIPFractional after 0 iterations and 0 nodes (3.39 seconds)
# NLP0014I      2        OPT         -6.3126e+008    25       0.865
# NLP0014I      3        OPT         -6.3107e+008    20       0.65
# NLP0014I      4        OPT         -6.3126e+008    25       0.784
# NLP0014I      5        OPT         -6.3107e+008    20       0.591
# NLP0014I      6        OPT         -6.3126e+008    25       0.777
# NLP0014I      7        OPT         -6.3107e+008    20       0.566
# NLP0014I      8        OPT         -6.3126e+008    25       0.767
# NLP0014I      9        OPT         -6.3107e+008    20       0.587
# NLP0014I      10       OPT         -6.3126e+008    25       0.756
# NLP0014I      11       OPT         -6.3107e+008    20       0.734
# NLP0014I      12       OPT         -6.3126e+008    25       0.806
# NLP0014I      13       OPT         -6.3107e+008    20       0.608
# NLP0014I      14       OPT         -6.3107e+008    22       0.634
# NLP0014I      15       OPT         -6.3126e+008    15       0.483
# NLP0014I      16       OPT         -6.3107e+008    22       0.636
# NLP0014I      17       OPT         -6.3126e+008    15       0.477
# NLP0014I      18       OPT         -6.3107e+008    22       0.694
# NLP0014I      19       OPT         -6.3126e+008    15       0.496
# NLP0014I      20       OPT         -6.3107e+008    22       0.689
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      21       OPT         -6.3126e+008    15       0.465
# NLP0014I      22       OPT         -6.3107e+008    22       0.672
# NLP0014I      23       OPT         -6.3126e+008    15       0.521
# NLP0014I      24       OPT         -6.3107e+008    22       0.701
# NLP0014I      25       OPT         -6.3126e+008    15       0.483
# Cbc0010I After 0 nodes, 1 on tree, -6.30955e+008 best solution, best possible -6.31323e+008 (18.85 seconds)
# NLP0014I      26       OPT         -6.3126e+008    25       0.856
# NLP0014I      27       OPT         -6.3107e+008    20       0.649
# NLP0014I      28       OPT         -6.312e+008     21       0.709
# NLP0014I      29       OPT         -6.3101e+008    30       1.017
# NLP0014I      30       OPT         -6.3114e+008    33       1.112
# NLP0014I      31       OPT         -6.3095e+008    24       0.711
# NLP0014I      32       OPT         -6.3108e+008    30       1.04
# NLP0014I      33       OPT         -6.3088e+008    34       1.007
# NLP0014I      34       OPT         -6.3102e+008    24       0.718
# NLP0014I      35       OPT         -6.3082e+008    32       0.908
# NLP0014I      36       OPT         -6.3095e+008    22       0.639
# NLP0014I      2        OPT         -6.3095e+008    7        0.203
# NLP0014I      3        OPT         -6.3095e+008    7        0.211
# NLP0014I      37       OPT         -6.3076e+008    51       1.538
# NLP0014I      38       OPT         -6.3101e+008    30       0.884
# NLP0014I      39       OPT         -6.3081e+008    20       0.57
# NLP0014I      40       OPT         -6.3095e+008    24       0.709
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      41       OPT         -6.3075e+008    47       1.497
# NLP0014I      42       OPT         -6.3095e+008    24       0.691
# NLP0014I      43       OPT         -6.3075e+008    47       1.496
# Cbc0001I Search completed - best objective -630954770.8039364, took 538 iterations and 18 nodes (36.09 seconds)
# Cbc0032I Strong branching done 12 times (492 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 5, 0 variables fixed on reduced cost
#
#  	"Finished"
# Bonmin 1.3 using Cbc 2.4.2 and Ipopt 3.8.1
# bonmin:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Common Public License (CPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.5146e+008    209      5.56
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.5145e+008    9        0.244
# NLP0014I      2        OPT         -6.5143e+008    9        0.272
# NLP0014I      3        OPT         -6.5142e+008    9        0.363
# NLP0014I      4        OPT         -6.514e+008     8        0.289
# NLP0014I      5        OPT         -6.5139e+008    8        0.306
# NLP0014I      6        OPT         -6.5137e+008    8        0.255
# NLP0014I      7        OPT         -6.5136e+008    8        0.33
# NLP0014I      8        OPT         -6.5134e+008    8        0.293
# NLP0014I      9        OPT         -6.5132e+008    8        0.238
# NLP0014I      10       OPT         -6.5131e+008    8        0.27
# NLP0014I      11       OPT         -6.5129e+008    8        0.257
# NLP0014I      12       OPT         -6.5128e+008    8        0.285
# NLP0014I      13       OPT         -6.5126e+008    8        0.25
# NLP0014I      14       OPT         -6.5124e+008    8        0.295
# NLP0014I      15       OPT         -6.5122e+008    8        0.29
# NLP0014I      16       OPT         -6.5121e+008    8        0.266
# NLP0014I      17       OPT         -6.5119e+008    8        0.253
# NLP0014I      18       OPT         -6.5117e+008    8        0.291
# NLP0014I      19       OPT         -6.5115e+008    8        0.245
# NLP0014I      20       OPT         -6.5113e+008    8        0.313
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      21       OPT         -6.5111e+008    8        0.337
# NLP0014I      22       OPT         -6.5109e+008    8        0.322
# NLP0014I      23       OPT         -6.5107e+008    8        0.301
# NLP0014I      24       OPT         -6.5105e+008    8        0.271
# NLP0014I      25       OPT         -6.5105e+008    7        0.227
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.5105e+008    7        0.25
# Cbc0012I Integer solution of -6.5105e+008 found by DiveMIPFractional after 0 iterations and 0 nodes (7.45 seconds)
# NLP0014I      2        OPT         -6.5144e+008    17       0.555
# NLP0014I      3        OPT         -6.51e+008      10       0.277
# NLP0014I      4        OPT         -6.5144e+008    17       0.573
# NLP0014I      5        OPT         -6.5143e+008    19       0.628
# NLP0014I      6        OPT         -6.5089e+008    14       0.409
# NLP0014I      7        OPT         -6.5143e+008    19       0.626
# NLP0014I      8        OPT         -6.5141e+008    30       0.905
# NLP0014I      9        OPT         -6.5088e+008    35       1.06
# NLP0014I      10       OPT         -6.5141e+008    30       0.859
# NLP0014I      11       OPT         -6.514e+008     25       0.784
# NLP0014I      12       OPT         -6.5086e+008    35       1.15
# NLP0014I      13       OPT         -6.514e+008     25       0.699
# NLP0014I      14       OPT         -6.5138e+008    30       0.847
# NLP0014I      15       OPT         -6.5085e+008    36       0.968
# NLP0014I      16       OPT         -6.5138e+008    30       0.806
# NLP0014I      17       OPT         -6.5137e+008    25       0.695
# NLP0014I      18       OPT         -6.508e+008     35       0.949
# NLP0014I      19       OPT         -6.5137e+008    25       0.692
# NLP0014I      20       OPT         -6.5135e+008    27       0.718
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      21       OPT         -6.5078e+008    16       0.461
# NLP0014I      22       OPT         -6.5135e+008    27       0.823
# NLP0014I      23       OPT         -6.5133e+008    37       1.034
# NLP0014I      24       OPT         -6.5077e+008    16       0.43
# NLP0014I      25       OPT         -6.5133e+008    37       1.014
# NLP0014I      26       OPT         -6.5132e+008    34       0.913
# NLP0014I      27       OPT         -6.5075e+008    15       0.415
# NLP0014I      28       OPT         -6.5132e+008    34       0.903
# NLP0014I      29       OPT         -6.513e+008     37       1.004
# NLP0014I      30       OPT         -6.5073e+008    15       0.42
# NLP0014I      31       OPT         -6.513e+008     37       0.987
# NLP0014I      32       OPT         -6.5129e+008    35       0.934
# NLP0014I      33       OPT         -6.5077e+008    17       0.483
# NLP0014I      34       OPT         -6.5129e+008    35       0.937
# NLP0014I      35       OPT         -6.5127e+008    23       0.638
# NLP0014I      36       OPT         -6.5075e+008    15       0.405
# NLP0014I      37       OPT         -6.5127e+008    23       0.639
# NLP0014I      38       OPT         -6.5125e+008    23       0.633
# NLP0014I      39       OPT         -6.5074e+008    15       0.415
# NLP0014I      40       OPT         -6.5125e+008    23       0.634
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      41       OPT         -6.5124e+008    20       0.537
# NLP0014I      42       OPT         -6.5072e+008    14       0.402
# NLP0014I      43       OPT         -6.5124e+008    20       0.548
# NLP0014I      44       OPT         -6.5122e+008    33       0.884
# NLP0014I      45       OPT         -6.5072e+008    36       0.969
# NLP0014I      46       OPT         -6.5122e+008    33       0.889
# NLP0014I      47       OPT         -6.512e+008     21       0.554
# NLP0014I      48       OPT         -6.507e+008     39       1.073
# NLP0014I      49       OPT         -6.512e+008     21       0.574
# NLP0014I      50       OPT         -6.5119e+008    23       0.624
# NLP0014I      51       OPT         -6.5068e+008    39       1.041
# NLP0014I      52       OPT         -6.5119e+008    23       0.605
# NLP0014I      53       OPT         -6.5117e+008    23       0.628
# NLP0014I      54       OPT         -6.5066e+008    39       1.05
# NLP0014I      55       OPT         -6.5117e+008    23       0.627
# NLP0014I      56       OPT         -6.5115e+008    22       0.584
# NLP0014I      57       OPT         -6.5065e+008    39       1.048
# NLP0014I      58       OPT         -6.5115e+008    22       0.606
# NLP0014I      59       OPT         -6.5113e+008    26       0.705
# NLP0014I      60       OPT         -6.5068e+008    36       0.953
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      61       OPT         -6.5113e+008    26       0.691
# NLP0014I      62       OPT         -6.5111e+008    24       0.657
# NLP0014I      63       OPT         -6.5066e+008    19       0.504
# NLP0014I      64       OPT         -6.5111e+008    24       0.65
# NLP0014I      65       OPT         -6.5109e+008    38       1.014
# NLP0014I      66       OPT         -6.5064e+008    18       0.505
# NLP0014I      67       OPT         -6.5109e+008    38       1.036
# NLP0014I      68       OPT         -6.5107e+008    21       0.556
# NLP0014I      69       OPT         -6.5062e+008    17       0.481
# NLP0014I      70       OPT         -6.5107e+008    21       0.558
# NLP0014I      71       OPT         -6.5105e+008    32       0.863
# NLP0014I      72       OPT         -6.506e+008     18       0.513
# NLP0014I      73       OPT         -6.5105e+008    32       0.842
# NLP0014I      2        OPT         -6.5105e+008    7        0.218
# NLP0014I      3        OPT         -6.5105e+008    7        0.196
# Cbc0001I Search completed - best objective -651050056.8648615, took 645 iterations and 0 nodes (60.13 seconds)
# Cbc0032I Strong branching done 24 times (1233 iterations), fathomed 0 nodes and fixed 24 variables
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
#
#  	"Finished"
# Bonmin 1.3 using Cbc 2.4.2 and Ipopt 3.8.1
# bonmin:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Common Public License (CPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    140      4.964
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    6        0.177
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    6        0.21
# Cbc0012I Integer solution of -6.46549e+008 found by DiveMIPFractional after 0 iterations and 0 nodes (0.41 seconds)
# NLP0014I      2        OPT         -6.4655e+008    6        0.274
# NLP0014I      3        OPT         -6.4655e+008    6        0.358
# Cbc0001I Search completed - best objective -646549170.2209907, took 0 iterations and 0 nodes (1.06 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
#
#  	"Finished"
# Bonmin 1.3 using Cbc 2.4.2 and Ipopt 3.8.1
# bonmin:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Common Public License (CPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    136      3.798
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    6        0.208
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I      1        OPT         -6.4655e+008    6        0.204
# Cbc0012I Integer solution of -6.46549e+008 found by DiveMIPFractional after 0 iterations and 0 nodes (0.43 seconds)
# NLP0014I      2        OPT         -6.4655e+008    6        0.187
# NLP0014I      3        OPT         -6.4655e+008    6        0.175
# Cbc0001I Search completed - best objective -646549170.2209907, took 0 iterations and 0 nodes (0.81 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
#
#  	"Finished"
# Ipopt 3.12.13:
# ==> Warning: Treating 0 binary and 120 integer variables as continous.
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:      240
# Number of nonzeros in Lagrangian Hessian.............:      360
#
# Total number of variables............................:      120
#                      variables with only lower bounds:      120
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:      240
#         inequality constraints with only lower bounds:      120
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      120
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -7.2870121e+09 9.65e+01 3.28e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -5.7854303e+09 9.64e+01 3.49e+01  -1.0 1.01e+02   2.0 9.84e-05 1.61e-03h  1
#    2 -4.0930346e+09 9.60e+01 1.66e+02  -1.0 5.88e+01   2.4 8.72e-05 8.41e-03h  1
#    3 -4.0686618e+09 9.60e+01 1.66e+02  -1.0 5.78e+01   1.9 5.24e-04 1.75e-04h  1
#    4 -4.0621128e+09 9.60e+01 1.68e+02  -1.0 6.28e+01   2.4 3.13e-03 1.40e-04h  1
#    5 -3.8934547e+09 9.59e+01 1.75e+02  -1.0 5.94e+01   1.9 4.60e-04 1.66e-03h  1
#    6 -3.8881224e+09 9.59e+01 1.77e+02  -1.0 6.31e+01   2.3 5.69e-03 2.34e-04h  1
#    7 -3.9206411e+09 9.59e+01 1.83e+02  -1.0 6.26e+01   1.8 3.71e-03 1.90e-03h  1
#    8 -3.5467086e+09 9.56e+01 1.85e+02  -1.0 7.87e+01   1.4 4.30e-03 4.48e-03h  1
#    9 -1.5577838e+09 9.41e+01 1.90e+02  -1.0 1.92e+02   0.9 1.26e-03 1.30e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -1.3710314e+09 9.22e+01 1.94e+02  -1.0 8.99e+01   0.4 2.26e-02 2.37e-02h  1
#   11 -1.1691197e+09 9.07e+01 1.92e+02  -1.0 9.21e+01  -0.1 4.72e-02 1.54e-02h  1
#   12 -5.8519916e+08 0.00e+00 2.45e+02  -1.0 9.14e+01    -  3.41e-03 1.00e+00h  1
#   13 -5.8512593e+08 0.00e+00 6.78e+00  -1.0 1.33e+00    -  9.79e-01 1.00e+00f  1
#   14 -5.8849647e+08 0.00e+00 3.90e-01  -1.0 1.10e+01    -  9.42e-01 1.00e+00f  1
#   15 -5.9359762e+08 0.00e+00 8.60e-02  -1.7 1.29e+01    -  7.80e-01 1.00e+00f  1
#   16 -6.0481757e+08 0.00e+00 8.24e-02  -2.5 9.86e+00    -  4.65e-02 6.91e-01f  1
#   17 -6.2206889e+08 0.00e+00 7.26e-02  -2.5 3.11e+01    -  1.19e-01 4.09e-01f  1
#   18 -6.4121577e+08 0.00e+00 6.00e-02  -2.5 3.19e+01    -  1.76e-01 6.69e-01f  1
#   19 -6.5293101e+08 0.00e+00 2.57e-02  -2.5 3.54e+01    -  5.71e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -6.5947531e+08 0.00e+00 1.64e-02  -3.8 2.36e+01    -  2.44e-02 4.90e-01f  1
#   21 -6.6598189e+08 0.00e+00 1.10e-02  -3.8 2.16e+01    -  1.88e-01 7.69e-01f  1
#   22 -6.6812829e+08 0.00e+00 4.51e-03  -3.8 1.95e+01    -  7.99e-01 5.92e-01f  1
#   23 -6.6847682e+08 0.00e+00 1.45e-04  -3.8 6.40e+00    -  1.00e+00 1.00e+00f  1
#   24 -6.6851753e+08 0.00e+00 7.43e-07  -5.7 1.61e-01    -  9.95e-01 1.00e+00f  1
#   25 -6.6851748e+08 0.00e+00 1.56e-10  -5.7 1.13e-02    -  1.00e+00 1.00e+00f  1
#   26 -6.6851798e+08 0.00e+00 4.03e-12  -8.6 8.47e-04    -  1.00e+00 1.00e+00f  1
#   27 -6.6851798e+08 0.00e+00 4.41e-17 -11.6 1.35e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 27
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.7962087859344555e+02   -6.6851797792738068e+08
# Dual infeasibility......:   4.4141031515180696e-17    1.6428531784964882e-10
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.4440987744230595e-12    9.0965147444263508e-06
# Overall NLP error.......:   2.4440987744230595e-12    9.0965147444263508e-06
#
#
# Number of objective function evaluations             = 28
# Number of objective gradient evaluations             = 28
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 28
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 28
# Number of Lagrangian Hessian evaluations             = 27
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.046
# Total CPU secs in NLP function evaluations           =      0.226
#
# EXIT: Optimal Solution Found.

# %%
revenues_optimal = [[], [], [], [], [], []]

for n in range(6):
    for w in range(W):
        revenues_optimal[n].append(sum(sum(f(s, p, w, r[n]) for p in range(P)) for s in range(S)))

# %%
growth = [0]
for n in range(1, 6):
    growth.append(round((sum(revenues_optimal[n]) - sum(revenues_optimal[0])) / sum(revenues_optimal[0]) * 100, 2))

# %%
plt.figure(figsize=(10, 6))
for n in range(0, 6):
    plt.plot(range(W), revenues_optimal[n], label=f'n = {n}, growth = {growth[n]} %')
plt.xlabel('Номер недели')
plt.ylabel('Выручка')
plt.legend(loc='upper right')
